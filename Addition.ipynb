# %%
from keras.models import Sequential
from keras.layers import LSTM, RepeatVector, Dense, Activation
from keras.layers.wrappers import TimeDistributed, Bidirectional
from keras.layers.normalization import BatchNormalization
from keras.optimizers import Adam
import numpy as np
from six.moves import range
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Parameters Config

# %%
class colors:
    ok = '\033[92m'
    fail = '\033[91m'
    close = '\033[0m'

# %%
TRAINING_SIZE = 100000
SPLIT_RATIO = 0.8
DIGITS = 3
REVERSE = False
MAXLEN = DIGITS + 1 + DIGITS
OUTPUTLEN = DIGITS + 1
chars = '0123456789+ '
HIDDEN_SIZE = 128
BATCH_SIZE = 128
LAYERS = 1

# %%
class CharacterTable(object):
    def __init__(self, chars):
        self.chars = sorted(set(chars))
        self.char_indices = dict((c, i) for i, c in enumerate(self.chars))
        self.indices_char = dict((i, c) for i, c in enumerate(self.chars))
    
    def encode(self, C, num_rows):
        x = np.zeros((num_rows, len(self.chars)))
        for i, c in enumerate(C):
            x[i, self.char_indices[c]] = 1
        return x
    
    def decode(self, x, calc_argmax=True):
        if calc_argmax:
            x = x.argmax(axis=-1)
        return "".join(self.indices_char[i] for i in x)

# %%
ctable = CharacterTable(chars)

# %% [markdown]
# # Data Generation

# %%
questions = []
expected = []
seen = set()
print('Generating data...')
while len(questions) < TRAINING_SIZE:
    f = lambda: int(''.join(np.random.choice(list('0123456789')) for i in range(np.random.randint(1, DIGITS + 1))))
    a, b = f(), f()
    key = tuple(sorted((a, b)))
    if key in seen:
        continue
    seen.add(key)
    q = '{}+{}'.format(a, b)
    query = q + ' ' * (MAXLEN - len(q))
    ans = str(a + b)
    ans += ' ' * (OUTPUTLEN - len(ans))
    if REVERSE:
        query = query[::-1]
    questions.append(query)
    expected.append(ans)
print('Total addition questions:', len(questions))
# Out:
# Generating data...
# Total addition questions: 100000

# %%
print(questions[:5], expected[:5])
# Out:
# ['1+56   ', '275+12 ', '3+1    ', '831+1  ', '6+4    '] ['57  ', '287 ', '4   ', '832 ', '10  ']

# %% [markdown]
# # Processing

# %%
print('Vectorization...')
x = np.zeros((len(questions), MAXLEN, len(chars)), dtype=np.bool)
y = np.zeros((len(expected), OUTPUTLEN, len(chars)), dtype=np.bool)
for i, sentence in enumerate(questions):
    x[i] = ctable.encode(sentence, MAXLEN)
for i, sentence in enumerate(expected):
    y[i] = ctable.encode(sentence, OUTPUTLEN)
# Out:
# Vectorization...

# %%
indices = np.arange(len(y))
np.random.shuffle(indices)
x = x[indices]
y = y[indices]

idx = int(SPLIT_RATIO * TRAINING_SIZE)

# train_test_split
train_x = x[:idx]
train_y = y[:idx]
test_x = x[idx:]
test_y = y[idx:]

split_at = len(train_x) - len(train_x) // 10
(x_train, x_val) = train_x[:split_at], train_x[split_at:]
(y_train, y_val) = train_y[:split_at], train_y[split_at:]

print('Training Data:')
print(x_train.shape)
print(y_train.shape)

print('Validation Data:')
print(x_val.shape)
print(y_val.shape)

print('Testing Data:')
print(test_x.shape)
print(test_y.shape)
# Out:
# Training Data:
# (72000, 7, 12)
# (72000, 4, 12)
# Validation Data:
# (8000, 7, 12)
# (8000, 4, 12)
# Testing Data:
# (20000, 7, 12)
# (20000, 4, 12)

# %%
print("input: ", x_train[:3], '\n\n', "label: ", y_train[:3])
# Out:
# input:  [[[False False False False  True False False False False False False
#    False]
#   [False False False False False False False False False False  True
#    False]
#   [False False False False False False False False False False False
#     True]
#   [False  True False False False False False False False False False
#    False]
#   [False False False False False False False False False  True False
#    False]
#   [False False False False False  True False False False False False
#    False]
#   [False False False False  True False False False False False False
#    False]]
#
#  [[False False False False False  True False False False False False
#    False]
#   [False False False False False  True False False False False False
#    False]
#   [False  True False False False False False False False False False
#    False]
#   [False False False False False False False  True False False False
#    False]
#   [False False False False False  True False False False False False
#    False]
#   [False False False False False False False False False  True False
#    False]
#   [ True False False False False False False False False False False
#    False]]
#
#  [[False False False False False False False False  True False False
#    False]
#   [False False  True False False False False False False False False
#    False]
#   [False False False False  True False False False False False False
#    False]
#   [False  True False False False False False False False False False
#    False]
#   [False False False False False False False False False False  True
#    False]
#   [False False False False False False  True False False False False
#    False]
#   [ True False False False False False False False False False False
#    False]]]
#
#  label:  [[[False False False  True False False False False False False False
#    False]
#   [False False  True False False False False False False False False
#    False]
#   [False False False False  True False False False False False False
#    False]
#   [False False False  True False False False False False False False
#    False]]
#
#  [[False False False False False False False  True False False False
#    False]
#   [False False False False False False False False False  True False
#    False]
#   [False False  True False False False False False False False False
#    False]
#   [ True False False False False False False False False False False
#    False]]
#
#  [[False False False False False False False False  True False False
#    False]
#   [False False False False False False False False False False  True
#    False]
#   [False False False False False False False False  True False False
#    False]
#   [ True False False False False False False False False False False
#    False]]]

# %% [markdown]
# # Build Model

# %%
print('Build model...')

def build_model():
    input_shape = (MAXLEN, len(chars))

    model = Sequential()

    # Encoder:
    model.add(Bidirectional(LSTM(20), input_shape=input_shape))
    model.add(BatchNormalization())

    # The RepeatVector-layer repeats the input n times
    model.add(RepeatVector(OUTPUTLEN))

    # Decoder:
    model.add(Bidirectional(LSTM(20, return_sequences=True)))
    model.add(BatchNormalization())

    model.add(TimeDistributed(Dense(len(chars))))
    model.add(Activation('softmax'))

    model.compile(
        loss='categorical_crossentropy',
        optimizer=Adam(lr=0.01),
        metrics=['accuracy'],
    )

    return model

model = build_model()
print(model.summary())
# Out:
# Build model...
# WARNING:tensorflow:From /Users/qoo/.local/share/virtualenvs/Adder_practice-uxw5uFhk/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_1 (Bidirection (None, 40)                5280
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 40)                160
# _________________________________________________________________
# repeat_vector_1 (RepeatVecto (None, 4, 40)             0
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 4, 40)             9760
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 4, 40)             160
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 4, 12)             492
# _________________________________________________________________
# activation_1 (Activation)    (None, 4, 12)             0
# =================================================================
# Total params: 15,852
# Trainable params: 15,692
# Non-trainable params: 160
# _________________________________________________________________
# None

# %% [markdown]
# # Training

# %%
for iteration in range(50):
    print()
    print('-' * 50)
    print('Iteration', iteration)
    history = model.fit(x_train, y_train,
                        batch_size=BATCH_SIZE,
                        epochs=1,
                        validation_data=(x_val, y_val))
    for i in range(10):
        ind = np.random.randint(0, len(x_val))
        rowx, rowy = x_val[np.array([ind])], y_val[np.array([ind])]
        preds = model.predict_classes(rowx, verbose=0)
        q = ctable.decode(rowx[0])
        correct = ctable.decode(rowy[0])
        guess = ctable.decode(preds[0], calc_argmax=False)
        print('Q', q[::-1] if REVERSE else q, end=' ')
        print('T', correct, end=' ')
        if correct == guess:
            print(colors.ok + '☑' + colors.close, end=' ')
        else:
            print(colors.fail + '☒' + colors.close, end=' ')
        print(guess)
# Out:
# --------------------------------------------------
# Iteration 0
# WARNING:tensorflow:From /Users/qoo/.local/share/virtualenvs/Adder_practice-uxw5uFhk/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /Users/qoo/.local/share/virtualenvs/Adder_practice-uxw5uFhk/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# Train on 72000 samples, validate on 8000 samples
# Epoch 1/1
# 72000/72000 [==============================] - 10s 145us/step - loss: 1.4768 - acc: 0.4596 - val_loss: 1.1772 - val_acc: 0.5507
# Q 49+418  T 467  ☒ 426
# Q 941+221 T 1162 ☒ 1234
# Q 1+265   T 266  ☒ 260
# Q 138+485 T 623  ☑ 623
# Q 62+129  T 191  ☒ 290
# Q 33+787  T 820  ☒ 811
# Q 446+638 T 1084 ☒ 1010
# Q 322+98  T 420  ☒ 421
# Q 413+49  T 462  ☒ 470
# Q 155+342 T 497  ☒ 589
#
# --------------------------------------------------
# Iteration 1
# Train on 72000 samples, validate on 8000 samples
# Epoch 1/1
# 72000/72000 [==============================] - 7s 102us/step - loss: 0.7473 - acc: 0.6984 - val_loss: 0.5908 - val_acc: 0.7531
# Q 315+19  T 334  ☒ 344
# Q 270+40  T 310  ☑ 310
# Q 72+316  T 388  ☒ 398
# Q 26+784  T 810  ☑ 810
# Q 681+767 T 1448 ☒ 1549
# Q 194+643 T 837  ☒ 846
# Q 61+636  T 697  ☒ 707
# Q 135+267 T 402  ☒ 412
# Q 52+101  T 153  ☑ 153
# Q 909+929 T 1838 ☒ 1848
#
# --------------------------------------------------
# Iteration 2
# Train on 72000 samples, validate on 8000 samples
# Epoch 1/1
# 72000/72000 [==============================] - 7s 99us/step - loss: 0.4241 - acc: 0.8322 - val_loss: 0.4204 - val_acc: 0.8275
# Q 50+496  T 546  ☑ 546
# Q 532+93  T 625  ☑ 625
# Q 68+7    T 75   ☑ 75
# Q 0+207   T 207  ☒ 217
# Q 846+928 T 1774 ☒ 1785
# Q 78+577  T 655  ☑ 655
# Q 70+609  T 679  ☑ 679
# Q 81+899  T 980  ☑ 980
# Q 686+57  T 743  ☑ 743
# Q 16+603  T 619  ☒ 618
#
# --------------------------------------------------
# Iteration 3
# Train on 72000 samples, validate on 8000 samples
# Epoch 1/1
# 72000/72000 [==============================] - 7s 101us/step - loss: 0.3056 - acc: 0.8839 - val_loss: 0.2018 - val_acc: 0.9315
# Q 65+261  T 326  ☑ 326
# Q 926+64  T 990  ☑ 990
# Q 97+970  T 1067 ☒ 1068
# Q 566+56  T 622  ☑ 622
# Q 383+542 T 925  ☑ 925
# Q 872+32  T 904  ☑ 904
# Q 375+725 T 1100 ☒ 1190
# Q 716+35  T 751  ☑ 751
# Q 354+33  T 387  ☑ 387
# Q 4+213   T 217  ☑ 217
#
# --------------------------------------------------
# Iteration 4
# Train on 72000 samples, validate on 8000 samples
# Epoch 1/1
# 72000/72000 [==============================] - 7s 101us/step - loss: 0.2371 - acc: 0.9125 - val_loss: 0.1617 - val_acc: 0.9413
# Q 95+375  T 470  ☑ 470
# Q 690+28  T 718  ☒ 719
# Q 853+67  T 920  ☑ 920
# Q 218+194 T 412  ☑ 412
# Q 342+12  T 354  ☑ 354
# Q 823+17  T 840  ☑ 840
# Q 250+432 T 682  ☒ 692
# Q 880+63  T 943  ☑ 943
# Q 6+68    T 74   ☑ 74
# Q 364+76  T 440  ☑ 440
#
# --------------------------------------------------
# Iteration 5
# Train on 72000 samples, validate on 8000 samples
# Epoch 1/1
# 72000/72000 [==============================] - 7s 102us/step - loss: 0.1947 - acc: 0.9303 - val_loss: 0.1269 - val_acc: 0.9553
# Q 54+532  T 586  ☑ 586
# Q 42+243  T 285  ☑ 285
# Q 414+72  T 486  ☑ 486
# Q 586+21  T 607  ☑ 607
# Q 228+33  T 261  ☑ 261
# Q 2+380   T 382  ☑ 382
# Q 555+28  T 583  ☑ 583
# Q 26+910  T 936  ☑ 936
# Q 889+417 T 1306 ☑ 1306
# Q 412+31  T 443  ☑ 443
#
# --------------------------------------------------
# Iteration 6
# Train on 72000 samples, validate on 8000 samples
# Epoch 1/1
# 72000/72000 [==============================] - 7s 104us/step - loss: 0.1686 - acc: 0.9404 - val_loss: 0.1790 - val_acc: 0.9486
# Q 794+265 T 1059 ☑ 1059
# Q 745+376 T 1121 ☑ 1121
# Q 30+58   T 88   ☑ 88
# Q 139+69  T 208  ☑ 208
# Q 92+94   T 186  ☑ 186
# Q 45+412  T 457  ☑ 457
# Q 3+319   T 322  ☒ 222
# Q 498+264 T 762  ☑ 762
# Q 44+818  T 862  ☑ 862
# Q 641+995 T 1636 ☑ 1636
#
# --------------------------------------------------
# Iteration 7
# Train on 72000 samples, validate on 8000 samples
# Epoch 1/1
# 72000/72000 [==============================] - 8s 104us/step - loss: 0.1392 - acc: 0.9519 - val_loss: 0.0989 - val_acc: 0.9662
# Q 689+137 T 826  ☑ 826
# Q 514+24  T 538  ☑ 538
# Q 173+978 T 1151 ☑ 1151
# Q 467+26  T 493  ☑ 493
# Q 33+234  T 267  ☑ 267
# Q 35+136  T 171  ☑ 171
# Q 653+425 T 1078 ☑ 1078
# Q 164+655 T 819  ☑ 819
# Q 817+1   T 818  ☑ 818
# Q 67+648  T 715  ☑ 715
#
# --------------------------------------------------
# Iteration 8
# Train on 72000 samples, validate on 8000 samples
# Epoch 1/1
# 72000/72000 [==============================] - 8s 105us/step - loss: 0.1242 - acc: 0.9572 - val_loss: 0.0944 - val_acc: 0.9673
# Q 420+32  T 452  ☑ 452
# Q 77+742  T 819  ☑ 819
# Q 926+644 T 1570 ☑ 1570
# Q 582+13  T 595  ☑ 595
# Q 451+42  T 493  ☑ 493
# Q 722+568 T 1290 ☑ 1290
# Q 20+722  T 742  ☑ 742
# Q 354+606 T 960  ☑ 960
# Q 484+112 T 596  ☑ 596
# Q 1+265   T 266  ☑ 266
#
# --------------------------------------------------
# Iteration 9
# Train on 72000 samples, validate on 8000 samples
# Epoch 1/1
# 72000/72000 [==============================] - 8s 105us/step - loss: 0.1202 - acc: 0.9602 - val_loss: 0.0636 - val_acc: 0.9807
# Q 93+868  T 961  ☑ 961
# Q 81+858  T 939  ☑ 939
# Q 668+717 T 1385 ☑ 1385
# Q 550+525 T 1075 ☑ 1075
# Q 58+333  T 391  ☑ 391
# Q 932+46  T 978  ☑ 978
# Q 726+161 T 887  ☑ 887
# Q 98+713  T 811  ☑ 811
# Q 514+723 T 1237 ☑ 1237
# Q 488+372 T 860  ☑ 860
#
# --------------------------------------------------
# Iteration 10
# Train on 72000 samples, validate on 8000 samples
# Epoch 1/1
# 72000/72000 [==============================] - 8s 105us/step - loss: 0.1024 - acc: 0.9657 - val_loss: 0.0818 - val_acc: 0.9712
# Q 40+460  T 500  ☑ 500
# Q 986+59  T 1045 ☑ 1045
# Q 731+43  T 774  ☑ 774
# Q 351+285 T 636  ☑ 636
# Q 467+26  T 493  ☒ 483
# Q 243+61  T 304  ☑ 304
# Q 256+424 T 680  ☒ 670
# Q 385+4   T 389  ☑ 389
# Q 1+845   T 846  ☑ 846
# Q 330+54  T 384  ☑ 384
#
# --------------------------------------------------
# Iteration 11
# Train on 72000 samples, validate on 8000 samples
# Epoch 1/1
# 72000/72000 [==============================] - 8s 104us/step - loss: 0.0916 - acc: 0.9698 - val_loss: 0.0345 - val_acc: 0.9902
# Q 926+64  T 990  ☑ 990
# Q 471+703 T 1174 ☑ 1174
# Q 867+44  T 911  ☑ 911
# Q 656+33  T 689  ☑ 689
# Q 314+13  T 327  ☑ 327
# Q 324+309 T 633  ☑ 633
# Q 300+804 T 1104 ☑ 1104
# Q 297+15  T 312  ☑ 312
# Q 67+250  T 317  ☑ 317
# Q 366+375 T 741  ☑ 741
#
# --------------------------------------------------
# Iteration 12
# Train on 72000 samples, validate on 8000 samples
# Epoch 1/1
# 72000/72000 [==============================] - 8s 106us/step - loss: 0.0895 - acc: 0.9701 - val_loss: 0.0455 - val_acc: 0.9855
# Q 55+450  T 505  ☑ 505
# Q 850+25  T 875  ☑ 875
# Q 690+165 T 855  ☑ 855
# Q 122+323 T 445  ☑ 445
# Q 791+792 T 1583 ☑ 1583
# Q 166+888 T 1054 ☑ 1054
# Q 596+56  T 652  ☑ 652
# Q 661+18  T 679  ☑ 679
# Q 358+60  T 418  ☑ 418
# Q 97+83   T 180  ☑ 180
#
# --------------------------------------------------
# Iteration 13
# Train on 72000 samples, validate on 8000 samples
# Epoch 1/1
# 72000/72000 [==============================] - 7s 101us/step - loss: 0.0738 - acc: 0.9760 - val_loss: 0.0308 - val_acc: 0.9920
# Q 43+60   T 103  ☑ 103
# Q 760+951 T 1711 ☑ 1711
# Q 30+699  T 729  ☒ 739
# Q 48+658  T 706  ☑ 706
# Q 464+71  T 535  ☑ 535
# Q 40+825  T 865  ☑ 865
# Q 90+737  T 827  ☑ 827
# Q 31+92   T 123  ☑ 123
# Q 239+8   T 247  ☑ 247
# Q 64+653  T 717  ☑ 717
#
# --------------------------------------------------
# Iteration 14
# Train on 72000 samples, validate on 8000 samples
# Epoch 1/1
# 72000/72000 [==============================] - 7s 102us/step - loss: 0.0745 - acc: 0.9767 - val_loss: 0.0356 - val_acc: 0.9889
# Q 695+943 T 1638 ☑ 1638
# Q 703+583 T 1286 ☑ 1286
# Q 1+54    T 55   ☑ 55
# Q 173+81  T 254  ☑ 254
# Q 545+786 T 1331 ☑ 1331
# Q 741+401 T 1142 ☑ 1142
# Q 69+168  T 237  ☑ 237
# Q 439+819 T 1258 ☑ 1258
# Q 570+48  T 618  ☑ 618
# Q 284+71  T 355  ☑ 355
#
# --------------------------------------------------
# Iteration 15
# Train on 72000 samples, validate on 8000 samples
# Epoch 1/1
# 72000/72000 [==============================] - 7s 103us/step - loss: 0.0657 - acc: 0.9795 - val_loss: 0.0507 - val_acc: 0.9840
# Q 386+968 T 1354 ☑ 1354
# Q 571+70  T 641  ☒ 651
# Q 18+43   T 61   ☑ 61
# Q 98+925  T 1023 ☑ 1023
# Q 60+138  T 198  ☑ 198
# Q 944+32  T 976  ☑ 976
# Q 2+813   T 815  ☑ 815
# Q 32+947  T 979  ☑ 979
# Q 512+13  T 525  ☑ 525
# Q 86+357  T 443  ☑ 443
#
# --------------------------------------------------
# Iteration 16
# Train on 72000 samples, validate on 8000 samples
# Epoch 1/1
# 72000/72000 [==============================] - 7s 103us/step - loss: 0.0595 - acc: 0.9812 - val_loss: 0.0221 - val_acc: 0.9934
# Q 599+59  T 658  ☑ 658
# Q 58+905  T 963  ☑ 963
# Q 476+280 T 756  ☑ 756
# Q 584+401 T 985  ☑ 985
# Q 28+541  T 569  ☑ 569
# Q 53+720  T 773  ☑ 773
# Q 389+971 T 1360 ☒ 1350
# Q 141+953 T 1094 ☑ 1094
# Q 801+41  T 842  ☑ 842
# Q 249+688 T 937  ☑ 937
#
# --------------------------------------------------
# Iteration 17
# Train on 72000 samples, validate on 8000 samples
# Epoch 1/1
# 72000/72000 [==============================] - 7s 103us/step - loss: 0.0494 - acc: 0.9846 - val_loss: 0.0182 - val_acc: 0.9948
# Q 265+379 T 644  ☑ 644
# Q 985+15  T 1000 ☑ 1000
# Q 166+888 T 1054 ☑ 1054
# Q 572+542 T 1114 ☑ 1114
# Q 877+544 T 1421 ☑ 1421
# Q 53+149  T 202  ☑ 202
# Q 957+617 T 1574 ☑ 1574
# Q 107+862 T 969  ☑ 969
# Q 594+471 T 1065 ☑ 1065
# Q 269+304 T 573  ☑ 573
#
# --------------------------------------------------
# Iteration 18
# Train on 72000 samples, validate on 8000 samples
# Epoch 1/1
# 72000/72000 [==============================] - 7s 103us/step - loss: 0.0612 - acc: 0.9821 - val_loss: 0.0250 - val_acc: 0.9929
# Q 591+629 T 1220 ☑ 1220
# Q 414+582 T 996  ☑ 996
# Q 383+542 T 925  ☑ 925
# Q 912+4   T 916  ☑ 916
# Q 56+912  T 968  ☑ 968
# Q 791+64  T 855  ☑ 855
# Q 80+918  T 998  ☑ 998
# Q 62+828  T 890  ☑ 890
# Q 104+68  T 172  ☑ 172
# Q 72+118  T 190  ☑ 190
#
# --------------------------------------------------
# Iteration 19
# Train on 72000 samples, validate on 8000 samples
# Epoch 1/1
# 72000/72000 [==============================] - 7s 103us/step - loss: 0.0494 - acc: 0.9857 - val_loss: 0.0781 - val_acc: 0.9840
# Q 868+10  T 878  ☑ 878
# Q 682+734 T 1416 ☑ 1416
# Q 84+685  T 769  ☑ 769
# Q 8+641   T 649  ☑ 649
# Q 618+11  T 629  ☑ 629
# Q 51+992  T 1043 ☑ 1043
# Q 796+627 T 1423 ☑ 1423
# Q 34+706  T 740  ☑ 740
# Q 9+472   T 481  ☑ 481
# Q 944+84  T 1028 ☑ 1028
#
# --------------------------------------------------
# Iteration 20
# Train on 72000 samples, validate on 8000 samples
# Epoch 1/1
# 72000/72000 [==============================] - 7s 104us/step - loss: 0.0473 - acc: 0.9858 - val_loss: 0.0153 - val_acc: 0.9956
# Q 51+312  T 363  ☑ 363
# Q 8+91    T 99   ☑ 99
# Q 588+26  T 614  ☑ 614
# Q 195+54  T 249  ☑ 249
# Q 53+729  T 782  ☑ 782
# Q 502+844 T 1346 ☑ 1346
# Q 872+81  T 953  ☑ 953
# Q 921+42  T 963  ☑ 963
# Q 656+22  T 678  ☑ 678
# Q 127+39  T 166  ☑ 166
#
# --------------------------------------------------
# Iteration 21
# Train on 72000 samples, validate on 8000 samples
# Epoch 1/1
# 72000/72000 [==============================] - 8s 104us/step - loss: 0.0363 - acc: 0.9895 - val_loss: 0.0174 - val_acc: 0.9952
# Q 69+821  T 890  ☑ 890
# Q 322+98  T 420  ☑ 420
# Q 36+71   T 107  ☑ 107
# Q 691+563 T 1254 ☑ 1254
# Q 213+520 T 733  ☑ 733
# Q 754+86  T 840  ☑ 840
# Q 266+743 T 1009 ☑ 1009
# Q 820+29  T 849  ☑ 849
# Q 38+373  T 411  ☑ 411
# Q 837+109 T 946  ☑ 946
#
# --------------------------------------------------
# Iteration 22
# Train on 72000 samples, validate on 8000 samples
# Epoch 1/1
# 72000/72000 [==============================] - 8s 105us/step - loss: 0.0511 - acc: 0.9848 - val_loss: 0.0224 - val_acc: 0.9960
# Q 368+19  T 387  ☑ 387
# Q 89+241  T 330  ☑ 330
# Q 88+994  T 1082 ☑ 1082
# Q 94+335  T 429  ☑ 429
# Q 217+735 T 952  ☑ 952
# Q 80+926  T 1006 ☑ 1006
# Q 968+51  T 1019 ☑ 1019
# Q 967+18  T 985  ☑ 985
# Q 869+355 T 1224 ☑ 1224
# Q 681+61  T 742  ☑ 742
#
# --------------------------------------------------
# Iteration 23
# Train on 72000 samples, validate on 8000 samples
# Epoch 1/1
# 72000/72000 [==============================] - 8s 104us/step - loss: 0.0336 - acc: 0.9899 - val_loss: 0.0434 - val_acc: 0.9889
# Q 277+487 T 764  ☑ 764
# Q 7+504   T 511  ☑ 511
# Q 230+700 T 930  ☑ 930
# Q 5+934   T 939  ☑ 939
# Q 333+157 T 490  ☑ 490
# Q 592+527 T 1119 ☑ 1119
# Q 587+829 T 1416 ☑ 1416
# Q 490+834 T 1324 ☑ 1324
# Q 63+794  T 857  ☑ 857
# Q 129+195 T 324  ☑ 324
#
# --------------------------------------------------
# Iteration 24
# Train on 72000 samples, validate on 8000 samples
# Epoch 1/1
# 72000/72000 [==============================] - 8s 105us/step - loss: 0.0379 - acc: 0.9891 - val_loss: 0.0177 - val_acc: 0.9948
# Q 138+89  T 227  ☑ 227
# Q 673+26  T 699  ☑ 699
# Q 397+792 T 1189 ☑ 1189
# Q 75+409  T 484  ☑ 484
# Q 841+83  T 924  ☑ 924
# Q 598+219 T 817  ☑ 817
# Q 76+627  T 703  ☑ 703
# Q 106+27  T 133  ☑ 133
# Q 281+43  T 324  ☑ 324
# Q 335+231 T 566  ☑ 566
#
# --------------------------------------------------
# Iteration 25
# Train on 72000 samples, validate on 8000 samples
# Epoch 1/1
# 72000/72000 [==============================] - 7s 104us/step - loss: 0.0427 - acc: 0.9879 - val_loss: 0.0114 - val_acc: 0.9975
# Q 56+350  T 406  ☑ 406
# Q 0+944   T 944  ☑ 944
# Q 170+4   T 174  ☑ 174
# Q 31+865  T 896  ☑ 896
# Q 288+965 T 1253 ☑ 1253
# Q 50+263  T 313  ☑ 313
# Q 120+64  T 184  ☑ 184
# Q 365+576 T 941  ☑ 941
# Q 641+46  T 687  ☑ 687
# Q 151+37  T 188  ☑ 188
#
# --------------------------------------------------
# Iteration 26
# Train on 72000 samples, validate on 8000 samples
# Epoch 1/1
# 72000/72000 [==============================] - 8s 105us/step - loss: 0.0320 - acc: 0.9903 - val_loss: 0.0095 - val_acc: 0.9976
# Q 638+250 T 888  ☑ 888
# Q 332+5   T 337  ☑ 337
# Q 653+3   T 656  ☑ 656
# Q 820+170 T 990  ☑ 990
# Q 73+7    T 80   ☑ 80
# Q 604+942 T 1546 ☑ 1546
# Q 958+844 T 1802 ☑ 1802
# Q 577+476 T 1053 ☑ 1053
# Q 534+466 T 1000 ☑ 1000
# Q 627+28  T 655  ☑ 655
#
# --------------------------------------------------
# Iteration 27
# Train on 72000 samples, validate on 8000 samples
# Epoch 1/1
# 72000/72000 [==============================] - 7s 102us/step - loss: 0.0276 - acc: 0.9920 - val_loss: 0.0114 - val_acc: 0.9969
# Q 36+692  T 728  ☑ 728
# Q 382+968 T 1350 ☑ 1350
# Q 827+128 T 955  ☑ 955
# Q 127+912 T 1039 ☑ 1039
# Q 295+20  T 315  ☑ 315
# Q 428+73  T 501  ☑ 501
# Q 289+389 T 678  ☑ 678
# Q 438+37  T 475  ☑ 475
# Q 9+537   T 546  ☑ 546
# Q 307+458 T 765  ☑ 765
#
# --------------------------------------------------
# Iteration 28
# Train on 72000 samples, validate on 8000 samples
# Epoch 1/1
# 72000/72000 [==============================] - 7s 102us/step - loss: 0.0446 - acc: 0.9882 - val_loss: 0.0055 - val_acc: 0.9989
# Q 387+244 T 631  ☑ 631
# Q 808+25  T 833  ☑ 833
# Q 47+82   T 129  ☑ 129
# Q 838+11  T 849  ☑ 849
# Q 34+868  T 902  ☑ 902
# Q 335+871 T 1206 ☑ 1206
# Q 379+48  T 427  ☑ 427
# Q 163+37  T 200  ☑ 200
# Q 8+867   T 875  ☑ 875
# Q 757+11  T 768  ☑ 768
#
# --------------------------------------------------
# Iteration 29
# Train on 72000 samples, validate on 8000 samples
# Epoch 1/1
# 72000/72000 [==============================] - 7s 103us/step - loss: 0.0278 - acc: 0.9924 - val_loss: 0.0189 - val_acc: 0.9968
# Q 122+399 T 521  ☑ 521
# Q 716+42  T 758  ☑ 758
# Q 748+90  T 838  ☑ 838
# Q 455+95  T 550  ☑ 550
# Q 466+198 T 664  ☑ 664
# Q 24+762  T 786  ☑ 786
# Q 28+541  T 569  ☑ 569
# Q 999+757 T 1756 ☑ 1756
# Q 36+407  T 443  ☑ 443
# Q 858+286 T 1144 ☑ 1144
#
# --------------------------------------------------
# Iteration 30
# Train on 72000 samples, validate on 8000 samples
# Epoch 1/1
# 72000/72000 [==============================] - 7s 103us/step - loss: 0.0514 - acc: 0.9866 - val_loss: 0.0213 - val_acc: 0.9942
# Q 290+403 T 693  ☑ 693
# Q 324+687 T 1011 ☑ 1011
# Q 42+113  T 155  ☑ 155
# Q 827+62  T 889  ☑ 889
# Q 86+504  T 590  ☑ 590
# Q 44+468  T 512  ☑ 512
# Q 531+80  T 611  ☑ 611
# Q 385+763 T 1148 ☑ 1148
# Q 514+44  T 558  ☑ 558
# Q 447+264 T 711  ☑ 711
#
# --------------------------------------------------
# Iteration 31
# Train on 72000 samples, validate on 8000 samples
# Epoch 1/1
# 72000/72000 [==============================] - 7s 103us/step - loss: 0.0180 - acc: 0.9945 - val_loss: 0.0033 - val_acc: 0.9992
# Q 130+67  T 197  ☑ 197
# Q 302+68  T 370  ☑ 370
# Q 854+24  T 878  ☑ 878
# Q 52+382  T 434  ☑ 434
# Q 358+60  T 418  ☑ 418
# Q 82+611  T 693  ☑ 693
# Q 546+78  T 624  ☑ 624
# Q 906+17  T 923  ☑ 923
# Q 262+23  T 285  ☑ 285
# Q 700+87  T 787  ☑ 787
#
# --------------------------------------------------
# Iteration 32
# Train on 72000 samples, validate on 8000 samples
# Epoch 1/1
# 72000/72000 [==============================] - 7s 104us/step - loss: 0.0231 - acc: 0.9934 - val_loss: 0.0056 - val_acc: 0.9989
# Q 58+636  T 694  ☑ 694
# Q 185+90  T 275  ☑ 275
# Q 1+678   T 679  ☑ 679
# Q 968+368 T 1336 ☑ 1336
# Q 356+508 T 864  ☑ 864
# Q 96+327  T 423  ☑ 423
# Q 563+620 T 1183 ☑ 1183
# Q 287+505 T 792  ☑ 792
# Q 49+320  T 369  ☑ 369
# Q 51+539  T 590  ☑ 590
#
# --------------------------------------------------
# Iteration 33
# Train on 72000 samples, validate on 8000 samples
# Epoch 1/1
# 72000/72000 [==============================] - 7s 103us/step - loss: 0.0331 - acc: 0.9908 - val_loss: 0.0055 - val_acc: 0.9987
# Q 748+76  T 824  ☑ 824
# Q 999+935 T 1934 ☑ 1934
# Q 942+54  T 996  ☑ 996
# Q 332+30  T 362  ☑ 362
# Q 725+10  T 735  ☑ 735
# Q 140+92  T 232  ☑ 232
# Q 82+306  T 388  ☑ 388
# Q 622+226 T 848  ☑ 848
# Q 259+673 T 932  ☑ 932
# Q 3+745   T 748  ☑ 748
#
# --------------------------------------------------
# Iteration 34
# Train on 72000 samples, validate on 8000 samples
# Epoch 1/1
# 72000/72000 [==============================] - 7s 104us/step - loss: 0.0273 - acc: 0.9919 - val_loss: 0.0189 - val_acc: 0.9954
# Q 486+97  T 583  ☑ 583
# Q 41+328  T 369  ☑ 369
# Q 13+845  T 858  ☑ 858
# Q 227+763 T 990  ☑ 990
# Q 29+537  T 566  ☑ 566
# Q 684+414 T 1098 ☑ 1098
# Q 212+466 T 678  ☑ 678
# Q 141+69  T 210  ☑ 210
# Q 32+868  T 900  ☑ 900
# Q 628+492 T 1120 ☑ 1120
#
# --------------------------------------------------
# Iteration 35
# Train on 72000 samples, validate on 8000 samples
# Epoch 1/1
# 72000/72000 [==============================] - 7s 103us/step - loss: 0.0297 - acc: 0.9920 - val_loss: 0.0045 - val_acc: 0.9993
# Q 647+187 T 834  ☑ 834
# Q 672+951 T 1623 ☑ 1623
# Q 36+463  T 499  ☑ 499
# Q 31+511  T 542  ☑ 542
# Q 32+276  T 308  ☑ 308
# Q 342+958 T 1300 ☑ 1300
# Q 708+878 T 1586 ☑ 1586
# Q 368+75  T 443  ☑ 443
# Q 750+185 T 935  ☑ 935
# Q 365+55  T 420  ☑ 420
#
# --------------------------------------------------
# Iteration 36
# Train on 72000 samples, validate on 8000 samples
# Epoch 1/1
# 72000/72000 [==============================] - 8s 105us/step - loss: 0.0422 - acc: 0.9892 - val_loss: 0.0142 - val_acc: 0.9969
# Q 376+12  T 388  ☑ 388
# Q 187+25  T 212  ☑ 212
# Q 736+781 T 1517 ☑ 1517
# Q 535+151 T 686  ☑ 686
# Q 587+168 T 755  ☑ 755
# Q 125+80  T 205  ☑ 205
# Q 96+256  T 352  ☑ 352
# Q 578+778 T 1356 ☑ 1356
# Q 616+32  T 648  ☑ 648
# Q 876+56  T 932  ☑ 932
#
# --------------------------------------------------
# Iteration 37
# Train on 72000 samples, validate on 8000 samples
# Epoch 1/1
# 72000/72000 [==============================] - 8s 104us/step - loss: 0.0165 - acc: 0.9954 - val_loss: 0.0119 - val_acc: 0.9961
# Q 111+714 T 825  ☑ 825
# Q 667+750 T 1417 ☑ 1417
# Q 703+20  T 723  ☑ 723
# Q 17+756  T 773  ☑ 773
# Q 60+602  T 662  ☑ 662
# Q 355+716 T 1071 ☑ 1071
# Q 976+90  T 1066 ☑ 1066
# Q 615+533 T 1148 ☑ 1148
# Q 912+933 T 1845 ☑ 1845
# Q 579+8   T 587  ☑ 587
#
# --------------------------------------------------
# Iteration 38
# Train on 72000 samples, validate on 8000 samples
# Epoch 1/1
# 72000/72000 [==============================] - 8s 105us/step - loss: 0.0303 - acc: 0.9919 - val_loss: 0.0104 - val_acc: 0.9972
# Q 48+602  T 650  ☑ 650
# Q 909+929 T 1838 ☑ 1838
# Q 242+897 T 1139 ☑ 1139
# Q 391+431 T 822  ☑ 822
# Q 38+191  T 229  ☑ 229
# Q 21+132  T 153  ☑ 153
# Q 712+477 T 1189 ☑ 1189
# Q 610+294 T 904  ☒ 004
# Q 86+108  T 194  ☑ 194
# Q 910+63  T 973  ☑ 973
#
# --------------------------------------------------
# Iteration 39
# Train on 72000 samples, validate on 8000 samples
# Epoch 1/1
# 72000/72000 [==============================] - 8s 105us/step - loss: 0.0120 - acc: 0.9965 - val_loss: 0.0047 - val_acc: 0.9988
# Q 158+85  T 243  ☑ 243
# Q 315+365 T 680  ☑ 680
# Q 83+922  T 1005 ☑ 1005
# Q 969+211 T 1180 ☑ 1180
# Q 168+31  T 199  ☑ 199
# Q 338+26  T 364  ☑ 364
# Q 53+65   T 118  ☑ 118
# Q 3+320   T 323  ☑ 323
# Q 282+0   T 282  ☑ 282
# Q 798+703 T 1501 ☑ 1501
#
# --------------------------------------------------
# Iteration 40
# Train on 72000 samples, validate on 8000 samples
# Epoch 1/1
# 72000/72000 [==============================] - 8s 106us/step - loss: 0.0361 - acc: 0.9908 - val_loss: 0.0036 - val_acc: 0.9992
# Q 387+244 T 631  ☑ 631
# Q 77+798  T 875  ☑ 875
# Q 8+142   T 150  ☑ 150
# Q 436+196 T 632  ☑ 632
# Q 731+3   T 734  ☑ 734
# Q 335+936 T 1271 ☑ 1271
# Q 67+226  T 293  ☑ 293
# Q 66+334  T 400  ☑ 400
# Q 683+0   T 683  ☑ 683
# Q 95+179  T 274  ☑ 274
#
# --------------------------------------------------
# Iteration 41
# Train on 72000 samples, validate on 8000 samples
# Epoch 1/1
# 72000/72000 [==============================] - 8s 105us/step - loss: 0.0185 - acc: 0.9948 - val_loss: 0.0065 - val_acc: 0.9982
# Q 195+619 T 814  ☑ 814
# Q 76+943  T 1019 ☑ 1019
# Q 566+56  T 622  ☑ 622
# Q 43+198  T 241  ☑ 241
# Q 45+179  T 224  ☑ 224
# Q 643+95  T 738  ☑ 738
# Q 823+925 T 1748 ☑ 1748
# Q 50+598  T 648  ☑ 648
# Q 901+767 T 1668 ☑ 1668
# Q 575+766 T 1341 ☑ 1341
#
# --------------------------------------------------
# Iteration 42
# Train on 72000 samples, validate on 8000 samples
# Epoch 1/1
# 72000/72000 [==============================] - 8s 105us/step - loss: 0.0283 - acc: 0.9928 - val_loss: 0.0077 - val_acc: 0.9976
# Q 60+528  T 588  ☑ 588
# Q 28+320  T 348  ☑ 348
# Q 69+283  T 352  ☑ 352
# Q 703+49  T 752  ☑ 752
# Q 304+779 T 1083 ☑ 1083
# Q 266+0   T 266  ☑ 266
# Q 819+290 T 1109 ☑ 1109
# Q 588+319 T 907  ☑ 907
# Q 733+911 T 1644 ☑ 1644
# Q 648+43  T 691  ☑ 691
#
# --------------------------------------------------
# Iteration 43
# Train on 72000 samples, validate on 8000 samples
# Epoch 1/1
# 72000/72000 [==============================] - 7s 102us/step - loss: 0.0189 - acc: 0.9948 - val_loss: 0.0039 - val_acc: 0.9991
# Q 92+445  T 537  ☑ 537
# Q 7+973   T 980  ☑ 980
# Q 426+41  T 467  ☑ 467
# Q 16+357  T 373  ☑ 373
# Q 243+714 T 957  ☑ 957
# Q 163+559 T 722  ☑ 722
# Q 864+584 T 1448 ☑ 1448
# Q 796+89  T 885  ☑ 885
# Q 664+176 T 840  ☑ 840
# Q 231+56  T 287  ☑ 287
#
# --------------------------------------------------
# Iteration 44
# Train on 72000 samples, validate on 8000 samples
# Epoch 1/1
# 72000/72000 [==============================] - 8s 105us/step - loss: 0.0269 - acc: 0.9929 - val_loss: 0.0042 - val_acc: 0.9989
# Q 939+458 T 1397 ☑ 1397
# Q 48+528  T 576  ☑ 576
# Q 69+283  T 352  ☑ 352
# Q 90+250  T 340  ☑ 340
# Q 82+827  T 909  ☑ 909
# Q 478+460 T 938  ☑ 938
# Q 51+244  T 295  ☑ 295
# Q 48+6    T 54   ☑ 54
# Q 20+974  T 994  ☑ 994
# Q 59+26   T 85   ☑ 85
#
# --------------------------------------------------
# Iteration 45
# Train on 72000 samples, validate on 8000 samples
# Epoch 1/1
# 72000/72000 [==============================] - 8s 105us/step - loss: 0.0232 - acc: 0.9937 - val_loss: 0.0111 - val_acc: 0.9971
# Q 739+6   T 745  ☑ 745
# Q 78+782  T 860  ☑ 860
# Q 528+745 T 1273 ☑ 1273
# Q 27+286  T 313  ☑ 313
# Q 566+581 T 1147 ☑ 1147
# Q 391+67  T 458  ☑ 458
# Q 924+56  T 980  ☑ 980
# Q 7+449   T 456  ☑ 456
# Q 32+83   T 115  ☑ 115
# Q 42+248  T 290  ☑ 290
#
# --------------------------------------------------
# Iteration 46
# Train on 72000 samples, validate on 8000 samples
# Epoch 1/1
# 72000/72000 [==============================] - 8s 105us/step - loss: 0.0178 - acc: 0.9953 - val_loss: 0.0065 - val_acc: 0.9992
# Q 878+957 T 1835 ☑ 1835
# Q 513+859 T 1372 ☑ 1372
# Q 523+4   T 527  ☑ 527
# Q 53+765  T 818  ☑ 818
# Q 471+49  T 520  ☑ 520
# Q 78+433  T 511  ☑ 511
# Q 619+616 T 1235 ☑ 1235
# Q 9+135   T 144  ☑ 144
# Q 65+500  T 565  ☑ 565
# Q 214+15  T 229  ☑ 229
#
# --------------------------------------------------
# Iteration 47
# Train on 72000 samples, validate on 8000 samples
# Epoch 1/1
# 72000/72000 [==============================] - 8s 105us/step - loss: 0.0337 - acc: 0.9922 - val_loss: 0.0049 - val_acc: 0.9988
# Q 52+678  T 730  ☑ 730
# Q 38+893  T 931  ☑ 931
# Q 616+769 T 1385 ☑ 1385
# Q 963+7   T 970  ☑ 970
# Q 685+197 T 882  ☑ 882
# Q 636+836 T 1472 ☑ 1472
# Q 808+54  T 862  ☑ 862
# Q 73+567  T 640  ☑ 640
# Q 4+686   T 690  ☑ 690
# Q 599+281 T 880  ☒ 870
#
# --------------------------------------------------
# Iteration 48
# Train on 72000 samples, validate on 8000 samples
# Epoch 1/1
# 72000/72000 [==============================] - 8s 105us/step - loss: 0.0082 - acc: 0.9978 - val_loss: 0.0016 - val_acc: 0.9998
# Q 450+690 T 1140 ☑ 1140
# Q 55+846  T 901  ☒ 900
# Q 880+286 T 1166 ☑ 1166
# Q 414+72  T 486  ☑ 486
# Q 11+562  T 573  ☑ 573
# Q 344+5   T 349  ☑ 349
# Q 82+103  T 185  ☑ 185
# Q 787+53  T 840  ☑ 840
# Q 743+29  T 772  ☑ 772
# Q 522+87  T 609  ☑ 609
#
# --------------------------------------------------
# Iteration 49
# Train on 72000 samples, validate on 8000 samples
# Epoch 1/1
# 72000/72000 [==============================] - 8s 105us/step - loss: 0.0291 - acc: 0.9923 - val_loss: 0.0116 - val_acc: 0.9976
# Q 686+811 T 1497 ☑ 1497
# Q 499+140 T 639  ☑ 639
# Q 43+824  T 867  ☑ 867
# Q 91+269  T 360  ☑ 360
# Q 60+677  T 737  ☑ 737
# Q 391+43  T 434  ☑ 434
# Q 691+563 T 1254 ☑ 1254
# Q 140+18  T 158  ☑ 158
# Q 312+510 T 822  ☑ 822
# Q 912+832 T 1744 ☑ 1744

# %% [markdown]
# # Testing

# %%
print("MSG : Prediction")
#####################################################
## Try to test and evaluate your model ##############
## ex. test_x = ["555+175", "860+7  ", "340+29 "]
## ex. test_y = ["730 ", "867 ", "369 "] 
#####################################################
# Out:
# MSG : Prediction

# %%
pred = model.predict_classes(test_x)

# %%
prediction = np.apply_along_axis(ctable.decode, 1, pred, False)

# %%
answer = np.apply_along_axis(lambda x: "".join(ctable.indices_char[i] for i in x), 1, test_y.argmax(axis=-1))

# %%
np.sum(prediction == answer) / answer.shape[0]
# Out:
# 0.98925
